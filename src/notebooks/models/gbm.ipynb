# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yaml

from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, classification_report
from sklearn.model_selection import train_test_split

import xgboost as xgb
import catboost as cat
import lightgbm as lgb

print(f'pd=={pd.__version__}')
print(f'np=={np.__version__}')
print(f'sns=={sns.__version__}')
# Out:
# pd==2.2.2
# np==1.26.4
# sns==0.13.2

# %%
with open('../../../config.yaml', 'r') as f:
    config = yaml.safe_load(f)
type(config)
# Out:
# dict

# %%
TARGET_FEATURE = config['data']['target_feature']
INDEX_COLUMN = config['data']['index_column']
RANDOM_STATE = config['model']['random_state']
TARGET_FEATURE, INDEX_COLUMN, RANDOM_STATE
# Out:
# ('isFraud', 'TransactionID', 42)

# %%
path_data = config['data']['path']
filename_train_pp = config['data']['train']['transaction']['pp']

dataset_pp = pd.read_csv(path_data+filename_train_pp, index_col=INDEX_COLUMN)
dataset_pp.shape
# Out:
# (590540, 274)

# %%
dataset_pp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 590540 entries, 2987000 to 3577539
# Columns: 274 entries, isFraud to P_domain_risk_group
# dtypes: float64(266), int64(8)
# memory usage: 1.2 GB

# %%
# Ensure chronological order of transactions
dataset_pp = dataset_pp.sort_values(by='TransactionDT', ascending=True)
dataset_pp['TransactionDT']
# Out:
# TransactionID
# 2987000       86400
# 2987001       86401
# 2987002       86469
# 2987003       86499
# 2987004       86506
#              ...
# 3577535    15811047
# 3577536    15811049
# 3577537    15811079
# 3577538    15811088
# 3577539    15811131
# Name: TransactionDT, Length: 590540, dtype: int64

# %%
# Data split: train, val, test

# Split data into Train, Val, Test : 70, 20, 10
# Split into chronological chunks - better representation of real life inference

#     train       val   test
# X X X X X X X | X X | X  Datapoints
# ------------------------> t

m = dataset_pp.shape[0]

y: pd.Series = dataset_pp[TARGET_FEATURE]
X: pd.DataFrame = dataset_pp.drop(columns=TARGET_FEATURE)

X_train = X.iloc[:int(m*0.7)]
y_train = y.iloc[:int(m*0.7)]
X_val = X.iloc[int(m*0.7):int(0.9*m)]
y_val = y.iloc[int(m*0.7):int(0.9*m)]
X_test = X.iloc[int(0.9*m):]
y_test = y.iloc[int(0.9*m):]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((413378, 273), (413378,), (118108, 273), (118108,), (59054, 273), (59054,))

# %%
# Scalers with default settings, which one yields the best result?
scaler_mm = MinMaxScaler(feature_range=(0, 1))
scaler_rb = RobustScaler(with_centering=True, with_scaling=True)
scaler_st = StandardScaler(with_mean=True, with_std=True)
scaler_st
# Out:
# StandardScaler()

# %%
# Data scaling
scaler_st.fit(X=X_train)
X_train_sc = pd.DataFrame(data=scaler_st.transform(X_train), index=X_train.index, columns=X_train.columns)
X_val_sc = pd.DataFrame(data=scaler_st.transform(X_val), index=X_val.index, columns=X_val.columns)
X_test_sc = pd.DataFrame(data=scaler_st.transform(X_test), index=X_test.index, columns=X_test.columns)

X_train_sc.shape, X_val_sc.shape, X_test_sc.shape
# Out:
# ((413378, 273), (118108, 273), (59054, 273))

# %%
estimator_xgb = xgb.XGBClassifier(
    n_estimators=200,       # Number of boosting rounds
    learning_rate=0.1,      # Step size shrinkage
    max_depth=8,            # Maximum depth of a tree
    min_child_weight=0.1,     # Minimum sum of instance weight (hessian) needed in a child
    gamma=0,                # Minimum loss reduction required to make a further partition
    # alpha=10,                # L1 Lasso regularisation
    early_stopping_rounds=10,
    eval_metric='auc',
    subsample=0.6,          # Subsample ratio of the training instances
    colsample_bytree=0.8,   # Subsample ratio of columns when constructing each tree
    objective='binary:logistic',  # Binary classification objective
    n_jobs=-1,              # Use all available cores
    random_state=RANDOM_STATE         # Seed for reproducibility
)

estimator_xgb.fit(
    X=X_train_sc, y=y_train, 
    eval_set=[(X_train_sc, y_train), (X_val_sc, y_val)],
)

y_pred = estimator_xgb.predict(X_test_sc)
y_prob = estimator_xgb.predict_proba(X_test_sc)[:, 1]

report_xgb = classification_report(y_true=y_test, y_pred=y_pred)
roc_aur_xgb = roc_auc_score(y_true=y_test, y_score=y_prob)

print(report_xgb)
print(roc_aur_xgb)
# Out:
# [0]	validation_0-auc:0.80893	validation_1-auc:0.78355
# [1]	validation_0-auc:0.82484	validation_1-auc:0.80266
# [2]	validation_0-auc:0.83687	validation_1-auc:0.80855
# [3]	validation_0-auc:0.86076	validation_1-auc:0.83171
# [4]	validation_0-auc:0.86408	validation_1-auc:0.83396
# [5]	validation_0-auc:0.86726	validation_1-auc:0.83274
# [6]	validation_0-auc:0.87183	validation_1-auc:0.83562
# [7]	validation_0-auc:0.87634	validation_1-auc:0.83611
# [8]	validation_0-auc:0.87871	validation_1-auc:0.83883
# [9]	validation_0-auc:0.88046	validation_1-auc:0.84040
# [10]	validation_0-auc:0.88171	validation_1-auc:0.84330
# [11]	validation_0-auc:0.88311	validation_1-auc:0.84513
# [12]	validation_0-auc:0.88396	validation_1-auc:0.84530
# [13]	validation_0-auc:0.88576	validation_1-auc:0.84774
# [14]	validation_0-auc:0.88776	validation_1-auc:0.84900
# [15]	validation_0-auc:0.88947	validation_1-auc:0.84989
# [16]	validation_0-auc:0.89076	validation_1-auc:0.85136
# [17]	validation_0-auc:0.89185	validation_1-auc:0.85216
# [18]	validation_0-auc:0.89365	validation_1-auc:0.85395
# [19]	validation_0-auc:0.89638	validation_1-auc:0.85571
# [20]	validation_0-auc:0.89819	validation_1-auc:0.85709
# [21]	validation_0-auc:0.90040	validation_1-auc:0.85848
# [22]	validation_0-auc:0.90187	validation_1-auc:0.85891
# [23]	validation_0-auc:0.90418	validation_1-auc:0.85995
# [24]	validation_0-auc:0.90557	validation_1-auc:0.86017
# [25]	validation_0-auc:0.90736	validation_1-auc:0.86104
# [26]	validation_0-auc:0.91036	validation_1-auc:0.86262
# [27]	validation_0-auc:0.91192	validation_1-auc:0.86335
# [28]	validation_0-auc:0.91388	validation_1-auc:0.86433
# [29]	validation_0-auc:0.91502	validation_1-auc:0.86487
# [30]	validation_0-auc:0.91673	validation_1-auc:0.86594
# [31]	validation_0-auc:0.91868	validation_1-auc:0.86782
# [32]	validation_0-auc:0.91917	validation_1-auc:0.86875
# [33]	validation_0-auc:0.92068	validation_1-auc:0.86929
# [34]	validation_0-auc:0.92213	validation_1-auc:0.87098
# [35]	validation_0-auc:0.92364	validation_1-auc:0.87144
# [36]	validation_0-auc:0.92479	validation_1-auc:0.87211
# [37]	validation_0-auc:0.92564	validation_1-auc:0.87238
# [38]	validation_0-auc:0.92657	validation_1-auc:0.87312
# [39]	validation_0-auc:0.92727	validation_1-auc:0.87370
# [40]	validation_0-auc:0.92856	validation_1-auc:0.87462
# [41]	validation_0-auc:0.92964	validation_1-auc:0.87478
# [42]	validation_0-auc:0.93146	validation_1-auc:0.87635
# [43]	validation_0-auc:0.93206	validation_1-auc:0.87691
# [44]	validation_0-auc:0.93372	validation_1-auc:0.87892
# [45]	validation_0-auc:0.93507	validation_1-auc:0.87976
# [46]	validation_0-auc:0.93648	validation_1-auc:0.88113
# [47]	validation_0-auc:0.93740	validation_1-auc:0.88196
# [48]	validation_0-auc:0.93782	validation_1-auc:0.88240
# [49]	validation_0-auc:0.93812	validation_1-auc:0.88270
# [50]	validation_0-auc:0.93874	validation_1-auc:0.88332
# [51]	validation_0-auc:0.93915	validation_1-auc:0.88358
# [52]	validation_0-auc:0.94008	validation_1-auc:0.88518
# [53]	validation_0-auc:0.94043	validation_1-auc:0.88559
# [54]	validation_0-auc:0.94099	validation_1-auc:0.88632
# [55]	validation_0-auc:0.94151	validation_1-auc:0.88663
# [56]	validation_0-auc:0.94206	validation_1-auc:0.88700
# [57]	validation_0-auc:0.94262	validation_1-auc:0.88769
# [58]	validation_0-auc:0.94304	validation_1-auc:0.88835
# [59]	validation_0-auc:0.94322	validation_1-auc:0.88865
# [60]	validation_0-auc:0.94349	validation_1-auc:0.88886
# [61]	validation_0-auc:0.94384	validation_1-auc:0.88909
# [62]	validation_0-auc:0.94477	validation_1-auc:0.88919
# [63]	validation_0-auc:0.94517	validation_1-auc:0.88944
# [64]	validation_0-auc:0.94537	validation_1-auc:0.88971
# [65]	validation_0-auc:0.94554	validation_1-auc:0.88973
# [66]	validation_0-auc:0.94610	validation_1-auc:0.89030
# [67]	validation_0-auc:0.94644	validation_1-auc:0.89090
# [68]	validation_0-auc:0.94773	validation_1-auc:0.89134
# [69]	validation_0-auc:0.94796	validation_1-auc:0.89154
# [70]	validation_0-auc:0.94813	validation_1-auc:0.89158
# [71]	validation_0-auc:0.94835	validation_1-auc:0.89178
# [72]	validation_0-auc:0.94855	validation_1-auc:0.89204
# [73]	validation_0-auc:0.94894	validation_1-auc:0.89290
# [74]	validation_0-auc:0.94916	validation_1-auc:0.89305
# [75]	validation_0-auc:0.94954	validation_1-auc:0.89321
# [76]	validation_0-auc:0.94986	validation_1-auc:0.89355
# [77]	validation_0-auc:0.95007	validation_1-auc:0.89362
# [78]	validation_0-auc:0.95158	validation_1-auc:0.89454
# [79]	validation_0-auc:0.95173	validation_1-auc:0.89453
# [80]	validation_0-auc:0.95306	validation_1-auc:0.89615
# [81]	validation_0-auc:0.95369	validation_1-auc:0.89668
# [82]	validation_0-auc:0.95445	validation_1-auc:0.89725
# [83]	validation_0-auc:0.95454	validation_1-auc:0.89734
# [84]	validation_0-auc:0.95492	validation_1-auc:0.89740
# [85]	validation_0-auc:0.95526	validation_1-auc:0.89758
# [86]	validation_0-auc:0.95545	validation_1-auc:0.89767
# [87]	validation_0-auc:0.95578	validation_1-auc:0.89783
# [88]	validation_0-auc:0.95598	validation_1-auc:0.89791
# [89]	validation_0-auc:0.95663	validation_1-auc:0.89810
# [90]	validation_0-auc:0.95697	validation_1-auc:0.89822
# [91]	validation_0-auc:0.95735	validation_1-auc:0.89863
# [92]	validation_0-auc:0.95760	validation_1-auc:0.89858
# [93]	validation_0-auc:0.95788	validation_1-auc:0.89868
# [94]	validation_0-auc:0.95810	validation_1-auc:0.89880
# [95]	validation_0-auc:0.95911	validation_1-auc:0.89923
# [96]	validation_0-auc:0.95994	validation_1-auc:0.89990
# [97]	validation_0-auc:0.96016	validation_1-auc:0.89996
# [98]	validation_0-auc:0.96040	validation_1-auc:0.90005
# [99]	validation_0-auc:0.96059	validation_1-auc:0.90018
# [100]	validation_0-auc:0.96103	validation_1-auc:0.90037
# [101]	validation_0-auc:0.96133	validation_1-auc:0.90059
# [102]	validation_0-auc:0.96149	validation_1-auc:0.90074
# [103]	validation_0-auc:0.96163	validation_1-auc:0.90085
# [104]	validation_0-auc:0.96222	validation_1-auc:0.90125
# [105]	validation_0-auc:0.96244	validation_1-auc:0.90134
# [106]	validation_0-auc:0.96275	validation_1-auc:0.90140
# [107]	validation_0-auc:0.96298	validation_1-auc:0.90136
# [108]	validation_0-auc:0.96332	validation_1-auc:0.90159
# [109]	validation_0-auc:0.96338	validation_1-auc:0.90163
# [110]	validation_0-auc:0.96347	validation_1-auc:0.90161
# [111]	validation_0-auc:0.96388	validation_1-auc:0.90192
# [112]	validation_0-auc:0.96392	validation_1-auc:0.90170
# [113]	validation_0-auc:0.96419	validation_1-auc:0.90200
# [114]	validation_0-auc:0.96441	validation_1-auc:0.90211
# [115]	validation_0-auc:0.96483	validation_1-auc:0.90228
# [116]	validation_0-auc:0.96509	validation_1-auc:0.90262
# [117]	validation_0-auc:0.96526	validation_1-auc:0.90295
# [118]	validation_0-auc:0.96547	validation_1-auc:0.90303
# [119]	validation_0-auc:0.96554	validation_1-auc:0.90307
# [120]	validation_0-auc:0.96566	validation_1-auc:0.90318
# [121]	validation_0-auc:0.96594	validation_1-auc:0.90387
# [122]	validation_0-auc:0.96603	validation_1-auc:0.90397
# [123]	validation_0-auc:0.96613	validation_1-auc:0.90385
# [124]	validation_0-auc:0.96630	validation_1-auc:0.90395
# [125]	validation_0-auc:0.96666	validation_1-auc:0.90394
# [126]	validation_0-auc:0.96687	validation_1-auc:0.90388
# [127]	validation_0-auc:0.96717	validation_1-auc:0.90395
# [128]	validation_0-auc:0.96750	validation_1-auc:0.90441
# [129]	validation_0-auc:0.96801	validation_1-auc:0.90471
# [130]	validation_0-auc:0.96855	validation_1-auc:0.90511
# [131]	validation_0-auc:0.96867	validation_1-auc:0.90507
# [132]	validation_0-auc:0.96890	validation_1-auc:0.90521
# [133]	validation_0-auc:0.96913	validation_1-auc:0.90533
# [134]	validation_0-auc:0.96946	validation_1-auc:0.90551
# [135]	validation_0-auc:0.96964	validation_1-auc:0.90551
# [136]	validation_0-auc:0.96979	validation_1-auc:0.90565
# [137]	validation_0-auc:0.97010	validation_1-auc:0.90583
# [138]	validation_0-auc:0.97034	validation_1-auc:0.90586
# [139]	validation_0-auc:0.97067	validation_1-auc:0.90610
# [140]	validation_0-auc:0.97071	validation_1-auc:0.90613
# [141]	validation_0-auc:0.97089	validation_1-auc:0.90617
# [142]	validation_0-auc:0.97098	validation_1-auc:0.90629
# [143]	validation_0-auc:0.97102	validation_1-auc:0.90629
# [144]	validation_0-auc:0.97114	validation_1-auc:0.90643
# [145]	validation_0-auc:0.97123	validation_1-auc:0.90632
# [146]	validation_0-auc:0.97133	validation_1-auc:0.90647
# [147]	validation_0-auc:0.97162	validation_1-auc:0.90681
# [148]	validation_0-auc:0.97196	validation_1-auc:0.90704
# [149]	validation_0-auc:0.97210	validation_1-auc:0.90715
# [150]	validation_0-auc:0.97222	validation_1-auc:0.90720
# [151]	validation_0-auc:0.97254	validation_1-auc:0.90736
# [152]	validation_0-auc:0.97273	validation_1-auc:0.90755
# [153]	validation_0-auc:0.97311	validation_1-auc:0.90790
# [154]	validation_0-auc:0.97326	validation_1-auc:0.90789
# [155]	validation_0-auc:0.97342	validation_1-auc:0.90774
# [156]	validation_0-auc:0.97343	validation_1-auc:0.90776
# [157]	validation_0-auc:0.97364	validation_1-auc:0.90800
# [158]	validation_0-auc:0.97371	validation_1-auc:0.90813
# [159]	validation_0-auc:0.97392	validation_1-auc:0.90815
# [160]	validation_0-auc:0.97398	validation_1-auc:0.90814
# [161]	validation_0-auc:0.97418	validation_1-auc:0.90816
# [162]	validation_0-auc:0.97435	validation_1-auc:0.90818
# [163]	validation_0-auc:0.97469	validation_1-auc:0.90864
# [164]	validation_0-auc:0.97475	validation_1-auc:0.90865
# [165]	validation_0-auc:0.97497	validation_1-auc:0.90875
# [166]	validation_0-auc:0.97510	validation_1-auc:0.90881
# [167]	validation_0-auc:0.97512	validation_1-auc:0.90889
# [168]	validation_0-auc:0.97538	validation_1-auc:0.90933
# [169]	validation_0-auc:0.97560	validation_1-auc:0.90931
# [170]	validation_0-auc:0.97577	validation_1-auc:0.90960
# [171]	validation_0-auc:0.97589	validation_1-auc:0.90966
# [172]	validation_0-auc:0.97599	validation_1-auc:0.90988
# [173]	validation_0-auc:0.97606	validation_1-auc:0.90986
# [174]	validation_0-auc:0.97614	validation_1-auc:0.90983
# [175]	validation_0-auc:0.97633	validation_1-auc:0.90990
# [176]	validation_0-auc:0.97655	validation_1-auc:0.90996
# [177]	validation_0-auc:0.97679	validation_1-auc:0.91004
# [178]	validation_0-auc:0.97685	validation_1-auc:0.91004
# [179]	validation_0-auc:0.97698	validation_1-auc:0.91013
# [180]	validation_0-auc:0.97705	validation_1-auc:0.91014
# [181]	validation_0-auc:0.97715	validation_1-auc:0.91026
# [182]	validation_0-auc:0.97736	validation_1-auc:0.91043
# [183]	validation_0-auc:0.97756	validation_1-auc:0.91066
# [184]	validation_0-auc:0.97775	validation_1-auc:0.91082
# [185]	validation_0-auc:0.97788	validation_1-auc:0.91116
# [186]	validation_0-auc:0.97808	validation_1-auc:0.91139
# [187]	validation_0-auc:0.97820	validation_1-auc:0.91133
# [188]	validation_0-auc:0.97823	validation_1-auc:0.91151
# [189]	validation_0-auc:0.97847	validation_1-auc:0.91172
# [190]	validation_0-auc:0.97865	validation_1-auc:0.91152
# [191]	validation_0-auc:0.97882	validation_1-auc:0.91196
# [192]	validation_0-auc:0.97895	validation_1-auc:0.91197
# [193]	validation_0-auc:0.97910	validation_1-auc:0.91192
# [194]	validation_0-auc:0.97931	validation_1-auc:0.91194
# [195]	validation_0-auc:0.97936	validation_1-auc:0.91209
# [196]	validation_0-auc:0.97946	validation_1-auc:0.91184
# [197]	validation_0-auc:0.97962	validation_1-auc:0.91182
# [198]	validation_0-auc:0.97971	validation_1-auc:0.91179
# [199]	validation_0-auc:0.97987	validation_1-auc:0.91181
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99     56841
#            1       0.80      0.31      0.44      2213
#
#     accuracy                           0.97     59054
#    macro avg       0.89      0.65      0.71     59054
# weighted avg       0.97      0.97      0.96     59054
#
# 0.9032119054354244

# %% [markdown]
# ```
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99     56841
#            1       0.80      0.31      0.44      2213
#
#     accuracy                           0.97     59054
#    macro avg       0.89      0.65      0.71     59054
# weighted avg       0.97      0.97      0.96     59054
#
# 0.9032448057337353
# ```

# %%
estimator_cat = cat.CatBoostClassifier(
    iterations=400,        # Number of boosting rounds
    learning_rate=0.1,      # Step size shrinkage
    depth=10,               # Depth of the tree
    l2_leaf_reg=3,          # L2 regularization term on weights
    loss_function='Logloss',# Binary classification objective
    border_count=32,        # Number of splits for numerical features
    verbose=100,            # Print the progress after each 100 iterations
    random_state=RANDOM_STATE,         # Seed for reproducibility
    colsample_bylevel = 0.6,
    early_stopping_rounds=10,
    eval_metric='AUC',
    scale_pos_weight=8,
)

estimator_cat.fit(
    X=X_train_sc, y=y_train,
    eval_set=[(X_train_sc, y_train), (X_val_sc, y_val)],
    use_best_model=True,
)

y_pred = estimator_cat.predict(X_test_sc)
y_prob = estimator_cat.predict_proba(X_test_sc)[:, 1]

report_cat = classification_report(y_true=y_test, y_pred=y_pred)
roc_aur_cat = roc_auc_score(y_true=y_test, y_score=y_prob)

print(report_cat)
print(roc_aur_cat)
# Out:
# 0:	test: 0.8258262	test1: 0.7928062	best: 0.7928062 (0)	total: 314ms	remaining: 2m 5s
# 100:	test: 0.9404926	test1: 0.8820432	best: 0.8820432 (100)	total: 30.2s	remaining: 1m 29s
# 200:	test: 0.9758069	test1: 0.9005670	best: 0.9005670 (200)	total: 1m	remaining: 59.8s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.9023367517
# bestIteration = 225
#
# Shrink model to first 226 iterations.
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     56841
#            1       0.50      0.51      0.50      2213
#
#     accuracy                           0.96     59054
#    macro avg       0.74      0.74      0.74     59054
# weighted avg       0.96      0.96      0.96     59054
#
# 0.8917945280694478

# %% [markdown]
# ```
#            0       0.98      0.97      0.97     56841
#            1       0.37      0.51      0.43      2213
#
#     accuracy                           0.95     59054
#    macro avg       0.68      0.74      0.70     59054
# weighted avg       0.96      0.95      0.95     59054
#
# 0.8820835620196221
# ```

# %%
# NOTE Only do if sufficient time

estimator_lgb = lgb.LGBMClassifier(
    n_estimators=100,       # Number of boosting rounds
    learning_rate=0.1,      # Step size shrinkage
    max_depth=-1,           # No limit on tree depth
    num_leaves=31,          # Maximum number of leaves in one tree
    min_child_weight=0.001, # Minimum sum of instance weight (hessian) needed in a child
    subsample=0.8,          # Subsample ratio of the training instances
    colsample_bytree=0.8,   # Subsample ratio of columns when constructing each tree
    objective='binary',     # Binary classification objective
    n_jobs=-1,              # Use all available cores
    random_state=RANDOM_STATE         # Seed for reproducibility
)

estimator_lgb.fit(X=X_train_sc, y=y_train)

y_pred = estimator_lgb.predict(X_test_sc)
y_prob = estimator_lgb.predict_proba(X_test_sc)[:, 1]

report_lgb = classification_report(y_true=y_test, y_pred=y_pred)
roc_aur_lgb = roc_auc_score(y_true=y_test, y_score=y_prob)

print(report_lgb)
print(roc_aur_lgb)
